# %%
import json
import unicodedata
import requests
from bs4 import BeautifulSoup, Tag
import csv
import headers

# %%
# resding csv file and generated links
def reading_csv():
    row = []
    all_links = []
    with open("Amazon Scraping - Sheet1.csv", "r", newline="") as file:
        content = csv.reader(file)
        next(content)
        for i in content:
            row.append(i)
    for i in row:
        link_format = "https://www.amazon.{country}/dp/{asin}"
        all_links.append(link_format.format(country=i[3], asin=i[2]))
    return all_links

# %%
# get price from string
def get_price(text):
    valid_character = "1234567890,."
    price = ""
    for i in text:
        if str(i) in valid_character:
            price = price+i
    return price

# %%
# removing control characters from string
def remove_control_characters(s):
    return "".join(ch for ch in s if unicodedata.category(ch)[0] != "C")

# %%
# get all details from link of product
def get_product_details(product_link, header):
    response = requests.get(product_link, headers=header)
    soup = BeautifulSoup(response.content, "html.parser")

    # checking if no data found page shown
    status = response.status_code
    if status == 404:
        print("Status: Not found")
        return "Not found"
    #checking if server error
    elif status>=500 and status<=600:
      print("Status: Server Error")
      return "Server Error"
    # checking if captcha verification found
    elif soup.find("form", {"action": "/errors/validateCaptcha"}):
        print("Status: Captcha")
        return "Captcha"

    # fetching product details
    else:

        # - fetching product_title
        product_title = soup.find("span", {"id": "productTitle"})
        product_title = product_title.text
        product_title = remove_control_characters(
            product_title).replace("\n", "").strip()

        # - fetching product image by '#imgBlkFront'
        # - checking if id changed and using alternate id
        product_image = soup.find("img", {"id": "imgBlkFront"})
        if not product_image:
            product_image = soup.find(
                "div", {"id": "imgTagWrapperId"}).select_one("img")["src"]
        else:
            product_image = product_image["src"]

        # - fetching product price by '#tmmSwatches'
        # - checking if id changed and using alternate id
        # - removing extra characters from price string
        product_price = soup.find(
            "div", {"id": "tmmSwatches"})
        if not product_price:
            product_price = soup.find("div", {
                "id": "corePriceDisplay_desktop_feature_div"}).select_one("span.a-offscreen")
        else:
            product_price = product_price.select_one(
                "a.a-button-text span.a-color-base")

        product_price = get_price(product_price.text)

        # - fetching product detail;s by '#detailBullets_feature_div'
        # - checking if id changed and using alternate id
        # - removing extra and invalid characters from product details string
        # - addind details in the form of dictionary {detail_heading : detail_text}
        all_product_details = soup.find(
            "div", {"id": "detailBullets_feature_div"})
        if not all_product_details:
            product_detail_row = soup.find("div", {"id": "prodDetails"}).select(
                "table#productDetails_techSpec_section_1 tr")
            product_details = []
            for detail in product_detail_row:
                heading = detail.select_one("th").text

                # removing special control character
                heading = remove_control_characters(
                    heading).replace("\n", "").strip()
                details = detail.select_one("td").text
                details = remove_control_characters(
                    details).replace("\n", "").strip()
                product_details.append({heading: details})
        else:
            all_product_details = all_product_details.select_one("ul")
            product_details = []
            for product_detail_items in all_product_details:
                if isinstance(product_detail_items, Tag):
                    title = product_detail_items.select_one(
                        "span.a-text-bold").text

                    # removing special control character
                    clean_title = remove_control_characters(
                        title).replace(":", "").strip()

                    detail = product_detail_items.find(
                        'span').find_next('span').find_next('span').text

                    clean_detail = remove_control_characters(
                        detail).replace(":", "").strip()
                    dic = {clean_title: clean_detail}
                    product_details.append(dic)

        product = {
            "product_title": product_title,
            "product_image": product_image,
            "product_price": product_price,
            "product_details": product_details
        }

        print("Status: Success")

        return product

# %%
# getting a list of all product details and bypass captcha by changing user agents for all link
def get_all_products_detail():
    products_list = []
    links = reading_csv()
    for idx, link in enumerate(links):
        current_header = headers.user_agents[idx % 5]
        print("Started #", idx, ": ", link)
        products_list.append(get_product_details(link, current_header))
    return products_list

# %%
# export data to JSON file
def export_to_json(json_data):
    json_object = json.dumps(json_data)
    with open("details_of_product.json", "w") as outfile:
        outfile.write(json_object)

# %%
all_products_details = get_all_products_detail()
all_products_details
# Out:
# Started # 0 :  https://www.amazon.de/dp/1015
# Status: Not found
# Started # 1 :  https://www.amazon.fr/dp/1015
# Status: Not found
# Started # 2 :  https://www.amazon.de/dp/000004458X
# Status: Success
# Started # 3 :  https://www.amazon.fr/dp/000004458X
# Status: Not found
# Started # 4 :  https://www.amazon.de/dp/1002198
# Status: Not found
# Started # 5 :  https://www.amazon.fr/dp/1002198
# Status: Not found
# Started # 6 :  https://www.amazon.fr/dp/1002791
# Status: Not found
# Started # 7 :  https://www.amazon.it/dp/1002791
# Status: Not found
# Started # 8 :  https://www.amazon.de/dp/1002864
# Status: Not found
# Started # 9 :  https://www.amazon.fr/dp/1002864
# Status: Not found
# Started # 10 :  https://www.amazon.de/dp/1003704
# Status: Not found
# Started # 11 :  https://www.amazon.fr/dp/1003704
# Status: Not found
# Started # 12 :  https://www.amazon.de/dp/1003763
# Status: Not found
# Started # 13 :  https://www.amazon.fr/dp/1003763
# Status: Not found
# Started # 14 :  https://www.amazon.fr/dp/1004271
# Status: Not found
# Started # 15 :  https://www.amazon.it/dp/1004271
# Status: Not found
# Started # 16 :  https://www.amazon.de/dp/000101742X
# Status: Success
# Started # 17 :  https://www.amazon.fr/dp/000101742X
# Status: Success
# Started # 18 :  https://www.amazon.de/dp/1017519
# Status: Not found
# Started # 19 :  https://www.amazon.fr/dp/1017519
# Status: Not found
# Started # 20 :  https://www.amazon.de/dp/000102163X
# Status: Success
# Started # 21 :  https://www.amazon.fr/dp/000102163X
# Status: Success
# Started # 22 :  https://www.amazon.fr/dp/1022369
# Status: Not found
# Started # 23 :  https://www.amazon.it/dp/1022369
# Status: Not found
# Started # 24 :  https://www.amazon.fr/dp/1022857
# Status: Not found
# Started # 25 :  https://www.amazon.it/dp/1022857
# Status: Not found
# Started # 26 :  https://www.amazon.de/dp/1032666
# Status: Not found
# Started # 27 :  https://www.amazon.fr/dp/1032666
# Status: Not found
# Started # 28 :  https://www.amazon.de/dp/1034677
# Status: Not found
# Started # 29 :  https://www.amazon.fr/dp/1034677
# Status: Not found
# Started # 30 :  https://www.amazon.de/dp/1034936
# Status: Not found
# Started # 31 :  https://www.amazon.fr/dp/1034936
# Status: Not found
# Started # 32 :  https://www.amazon.de/dp/1034944
# Status: Not found
# Started # 33 :  https://www.amazon.fr/dp/1034944
# Status: Not found
# Started # 34 :  https://www.amazon.de/dp/1035002
# Status: Not found
# Started # 695 :  https://www.amazon.de/dp/000417271X
# Status: Success
# Started # 696 :  https://www.amazon.fr/dp/000417271X
# Status: Captcha
# Started # 697 :  https://www.amazon.de/dp/4172736
# Status: Captcha
# Started # 698 :  https://www.amazon.fr/dp/4172736
# Status: Captcha
# Started # 699 :  https://www.amazon.de/dp/4172744
# Status: Not found
# Started # 700 :  https://www.amazon.fr/dp/4172744
# Status: Not found
# Started # 701 :  https://www.amazon.de/dp/4172833
# Status: Captcha
# Started # 702 :  https://www.amazon.fr/dp/4172833
# Status: Captcha
# Started # 703 :  https://www.amazon.de/dp/4172841
# Status: Captcha
# Started # 704 :  https://www.amazon.fr/dp/4172841
# Status: Not found
# Started # 705 :  https://www.amazon.de/dp/4172884
# Status: Not found
# Started # 706 :  https://www.amazon.fr/dp/4172884
# Status: Captcha
# Started # 707 :  https://www.amazon.de/dp/4172906
# Status: Captcha
# ...
#    {'Lingua': 'Tedesco'},
#    {'Copertina flessibile': '36 pagine'},
#    {'ISBN-10': '000416198X'},
#    {'ISBN-13': '978-0004161983'},
#    {'Peso articolo': '1 kg'}]},
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  {'product_title': "Il Re pastore KV 208 - L'amerò, sarò costante - Arie der Aminta - Ausgabe für Sorpan, Violine und Klavier (EB 5473)",
#   'product_image': 'https://images-eu.ssl-images-amazon.com/images/I/41YwjHe4wkL._SX198_BO1,204,203,200_QL40_ML2_.jpg',
#   'product_price': '7,90',
#   'product_details': [{'Herausgeber': 'Breitkopf & Härtel (5. November 1963)'},
#    {'Sprache': 'Deutsch'},
#    {'Musiknoten': '10 Seiten'},
#    {'ISBN-10': '000416413X'},
#    {'ISBN-13': '978-0004164137'}]},
#  {'product_title': "L'amero/dein bin ich kv 208",
#   'product_image': 'https://images-eu.ssl-images-amazon.com/images/I/41YwjHe4wkL._SX218_BO1,204,203,200_QL40_ML2_.jpg',
#   'product_price': '10,55',
#   'product_details': [{'Éditeur': 'BREITKOPF (1 janvier 2000)'},
#    {'Langue': 'Allemand'},
#    {'Partition': '10 pages'},
#    {'ISBN-10': '000416413X'},
#    {'ISBN-13': '978-0004164137'},
#    {"Poids de l'article": '201 g'}]},
#  {'product_title': 'Sonate op. 41 - Ausgabe für Fagott und Klavier (EB 5567)',
#   'product_image': 'https://images-eu.ssl-images-amazon.com/images/I/41aptNQZHrL._SX198_BO1,204,203,200_QL40_ML2_.jpg',
#   'product_price': '35,90',
#   'product_details': [{'Herausgeber': 'Breitkopf & Härtel (21. März 1961)'},
#    {'Sprache': 'Deutsch'},
#    {'Taschenbuch': '36 Seiten'},
#    {'ISBN-10': '000416444X'},
#    {'ISBN-13': '978-0004164441'}]},
#  {'product_title': 'Sonate op. 41 basson',
#   'product_image': 'https://images-eu.ssl-images-amazon.com/images/I/41aptNQZHrL._SX218_BO1,204,203,200_QL40_ML2_.jpg',
#   'product_price': '30,75',
#   'product_details': [{'Éditeur': 'BREITKOPF (1 janvier 2000)'},
#    {'Langue': 'Allemand'},
#    {'Broché': '36 pages'},
#    {'ISBN-10': '000416444X'},
#    {'ISBN-13': '978-0004164441'},
#    {"Poids de l'article": '140 g'}]},
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Captcha',
#  'Not found',
#  'Not found',
#  {'product_title': 'Quintett B-dur op. 34 - Breitkopf Urtext - Stimmensatz (EB 5830)',
#   'product_image': 'https://images-eu.ssl-images-amazon.com/images/I/41QN-6dasEL._SX198_BO1,204,203,200_QL40_ML2_.jpg',
#   'product_price': '25,90',
#   'product_details': [{'Herausgeber': 'Breitkopf & Härtel (29. April 1966)'},
#    {'Sprache': 'Deutsch'},
#    {'Taschenbuch': '68 Seiten'},
#    {'ISBN-10': '000416508X'},
#    {'ISBN-13': '978-0004165080'},
#    {'Abmessungen': '30.51 x 23.01 x 0.48 cm'}]},
#  {'product_title': 'Quintett b-dur op. 34 clarinette',
#   'product_image': 'https://images-eu.ssl-images-amazon.com/images/I/41QN-6dasEL._SX218_BO1,204,203,200_QL40_ML2_.jpg',
#   'product_price': '36,44',
#   'product_details': [{'Éditeur': 'BREITKOPF (1 janvier 2000)'},
#    {'Langue': 'Allemand'},
#    {'Broché': '68 pages'},
#    {'ISBN-10': '000416508X'},
#    {'ISBN-13': '978-0004165080'},
#    {"Poids de l'article": '500 g'},
#    {'Dimensions': '30.51 x 23.01 x 0.48 cm'}]},
#  'Captcha',
#  {'product_title': 'Sonate bes flute traversiere',
#   'product_image': 'https://images-eu.ssl-images-amazon.com/images/I/515ZbxjDfLL._SY291_BO1,204,203,200_QL40_ML2_.jpg',
#   'product_price': '20,96',
#   'product_details': [{'Éditeur': 'BREITKOPF (1 janvier 2000)'},
#    {'Langue': 'Allemand'},
#    {'Partition': '36 pages'},
#    {'ISBN-10': '000416511X'},
#    {'ISBN-13': '979-0004165119'},
#    {"Poids de l'article": '501 g'}]},
#  'Not found',
#  'Not found',
#  'Not found',
#  'Captcha',
#  'Not found',
#  'Captcha',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Captcha',
#  'Not found',
#  'Not found',
#  'Captcha',
#  'Captcha',
#  'Captcha',
#  {'product_title': 'Chaconne d-moll aus bwv 1004',
#   'product_image': 'https://images-eu.ssl-images-amazon.com/images/I/41lrIDbi75L._SY291_BO1,204,203,200_QL40_ML2_.jpg',
#   'product_price': '13,93',
#   'product_details': [{'Éditeur': 'BREITKOPF (1 janvier 2000)'},
#    {'Langue': 'Allemand'},
#    {'Partition': '16 pages'},
#    {'ISBN-10': '000416816X'},
#    {'ISBN-13': '978-0004168166'},
#    {"Poids de l'article": '401 g'}]},
#  {'product_title': 'Chaconne aus der Partita II d-moll BWV 1004 Bearbeitung für Cembalo (EB 6594)',
#   'product_image': 'https://images-eu.ssl-images-amazon.com/images/I/41lrIDbi75L._SY264_BO1,204,203,200_QL40_ML2_.jpg',
#   'product_price': '13,93',
#   'product_details': [{'Editore': 'Breitkopf & Härtel (1 gennaio 2000)'},
#    {'Lingua': 'Tedesco'},
#    {'Spartito musicale': '16 pagine'},
#    {'ISBN-10': '000416816X'},
#    {'ISBN-13': '978-0004168166'},
#    {'Peso articolo': '401 g'}]},
#  'Captcha',
#  'Captcha',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Captcha',
#  'Captcha',
#  'Captcha',
#  'Not found',
#  'Not found',
#  'Captcha',
#  'Captcha',
#  'Captcha',
#  'Not found',
#  'Not found',
#  'Captcha',
#  'Captcha',
#  'Captcha',
#  {'product_title': 'LITANIAE DE VENERABILI KV 243',
#   'product_image': 'https://images-na.ssl-images-amazon.com/images/I/414wyAfP+WL._SY344_BO1,204,203,200_.jpg',
#   'product_price': '15,40',
#   'product_details': [{'Herausgeber': 'BREITKOPF (1. Januar 2000)'},
#    {'Sprache': 'Französisch'},
#    {'ISBN-10': '000416976X'},
#    {'ISBN-13': '979-0004169766'}]},
#  {'product_title': 'Litaniae de venerabili kv 243',
#   'product_image': 'https://images-na.ssl-images-amazon.com/images/I/414wyAfP+WL._SY344_BO1,204,203,200_.jpg',
#   'product_price': '16,26',
#   'product_details': [{'Éditeur': 'BREITKOPF (1 janvier 2000)'},
#    {'Langue': 'Français'},
#    {'ISBN-10': '000416976X'},
#    {'ISBN-13': '979-0004169766'},
#    {"Poids de l'article": '501 g'}]},
#  'Captcha',
#  'Captcha',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Captcha',
#  'Captcha',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Captcha',
#  'Captcha',
#  'Captcha',
#  'Not found',
#  'Not found',
#  'Captcha',
#  'Captcha',
#  'Captcha',
#  'Not found',
#  'Not found',
#  'Captcha',
#  'Captcha',
#  'Captcha',
#  'Not found',
#  'Not found',
#  'Captcha',
#  'Captcha',
#  'Captcha',
#  'Not found',
#  'Not found',
#  'Captcha',
#  'Captcha',
#  'Captcha',
#  'Not found',
#  'Not found',
#  'Captcha',
#  'Captcha',
#  'Captcha',
#  'Not found',
#  'Not found',
#  'Captcha',
#  'Captcha',
#  'Captcha',
#  'Not found',
#  {'product_title': 'Kantate 52 Falsche Welt, Dir',
#   'product_image': 'https://images-eu.ssl-images-amazon.com/images/I/41mTrzyK76L._SY264_BO1,204,203,200_QL40_ML2_.jpg',
#   'product_price': '7,39',
#   'product_details': [{'Herausgeber': 'BREITKOPF; Klavierauszug Leipzig 1984 Edition (1. Januar 2000)'},
#    {'Sprache': 'Französisch'},
#    {'Musiknoten': '20 Seiten'},
#    {'ISBN-10': '000417206X'},
#    {'ISBN-13': '978-0004172064'}]},
#  'Captcha',
#  'Captcha',
#  'Captcha',
#  'Not found',
#  'Not found',
#  'Captcha',
#  'Captcha',
#  'Captcha',
#  'Not found',
#  'Not found',
#  'Captcha',
#  'Captcha',
#  'Captcha',
#  'Not found',
#  'Not found',
#  'Captcha',
#  'Captcha',
#  'Captcha',
#  'Not found',
#  {'product_title': 'Kantate 86 Wahrlich, Wahrlich',
#   'product_image': 'https://images-eu.ssl-images-amazon.com/images/I/41aWBN0BW1L._SY264_BO1,204,203,200_QL40_ML2_.jpg',
#   'product_price': '6,50',
#   'product_details': [{'Herausgeber': 'BREITKOPF; Klavierauszug Leipzig 1983 Edition (1. Januar 2000)'},
#    {'Sprache': 'Französisch'},
#    {'Taschenbuch': '20 Seiten'},
#    {'ISBN-10': '000417240X'},
#    {'ISBN-13': '979-0004172407'}]},
#  'Captcha',
#  'Captcha',
#  'Captcha',
#  'Not found',
#  'Not found',
#  'Captcha',
#  'Captcha',
#  'Captcha',
#  'Not found',
#  'Not found',
#  'Captcha',
#  'Captcha',
#  'Captcha',
#  'Not found',
#  'Not found',
#  'Captcha',
#  'Captcha',
#  'Captcha',
#  'Not found',
#  'Not found',
#  'Captcha',
#  'Captcha',
#  'Not found',
#  {'product_title': 'Kantate 114 Ach Lieben',
#   'product_image': 'https://images-eu.ssl-images-amazon.com/images/I/41mIiAzCWsL._SY264_BO1,204,203,200_QL40_ML2_.jpg',
#   'product_price': '8,50',
#   'product_details': [{'Herausgeber': 'BREITKOPF; Klavierauszug Leipzig 1985 Edition (1. Januar 2000)'},
#    {'Sprache': 'Französisch'},
#    {'Taschenbuch': '28 Seiten'},
#    {'ISBN-10': '000417268X'},
#    {'ISBN-13': '979-0004172681'}]},
#  {'product_title': 'Kantate 114 ach lieben',
#   'product_image': 'https://images-eu.ssl-images-amazon.com/images/I/41mIiAzCWsL._SY291_BO1,204,203,200_QL40_ML2_.jpg',
#   'product_price': '9,00',
#   'product_details': [{'Éditeur': 'BREITKOPF (1 janvier 2000)'},
#    {'Langue': 'Français'},
#    {'ISBN-10': '000417268X'},
#    {'ISBN-13': '979-0004172681'},
#    {"Poids de l'article": '201 g'}]},
#  'Captcha',
#  'Captcha',
#  'Captcha',
#  'Not found',
#  {'product_title': 'Kantate 117 Sie Lob Und Ehr',
#   'product_image': 'https://images-eu.ssl-images-amazon.com/images/I/41hlFmvlMsL._SY264_BO1,204,203,200_QL40_ML2_.jpg',
#   'product_price': '9,15',
#   'product_details': [{'Herausgeber': 'BREITKOPF; Klavierauszug deutsch/englisch Edition (1. Januar 2000)'},
#    {'Sprache': 'Französisch'},
#    {'Broschüre': '28 Seiten'},
#    {'ISBN-10': '000417271X'},
#    {'ISBN-13': '978-0004172712'}]},
#  'Captcha',
#  'Captcha',
#  'Captcha',
#  'Not found',
#  'Not found',
#  'Captcha',
#  'Captcha',
#  'Captcha',
#  'Not found',
#  'Not found',
#  'Captcha',
#  'Captcha',
#  'Captcha',
#  'Not found',
#  'Not found',
#  'Captcha',
#  'Captcha',
#  'Captcha',
#  'Not found',
#  'Not found',
#  'Captcha',
#  'Captcha',
#  'Captcha',
#  'Not found',
#  'Not found',
#  'Captcha',
#  'Captcha',
#  'Captcha',
#  'Not found',
#  {'product_title': 'Bach, Kantate 164, Ihr, die ihr euch von Christo nennet',
#   'product_image': 'https://images-na.ssl-images-amazon.com/images/I/41+g+QbpBFL._SX258_BO1,204,203,200_.jpg',
#   'product_price': '7,39',
#   'product_details': [{'Herausgeber': 'BREITKOPF; Klavierauszug Leipzig 1986 Edition (1. Januar 2000)'},
#    {'Sprache': 'Französisch'},
#    {'Taschenbuch': '20 Seiten'},
#    {'ISBN-10': '000417318X'},
#    {'ISBN-13': '979-0004173183'}]},
#  'Captcha',
#  'Captcha',
#  'Captcha',
#  'Not found',
#  'Not found',
#  'Captcha',
#  'Captcha',
#  'Captcha',
#  'Not found',
#  'Not found',
#  'Captcha',
#  'Captcha',
#  'Captcha',
#  'Not found',
#  'Not found',
#  'Captcha',
#  'Captcha',
#  'Captcha',
#  {'product_title': 'Kantate 181 leichtgesinnte',
#   'product_image': 'https://images-eu.ssl-images-amazon.com/images/I/31D4bTOuJaL._SY291_BO1,204,203,200_QL40_ML2_.jpg',
#   'product_price': '2,68',
#   'product_details': [{'Éditeur': 'BREITKOPF (1 janvier 2000)'},
#    {'Langue': 'Français'},
#    {'ISBN-10': '000417335X'},
#    {'ISBN-13': '978-0004173351'},
#    {"Poids de l'article": '201 g'}]},
#  'Not found',
#  'Captcha',
#  'Not found',
#  'Captcha',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Captcha',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Captcha',
#  'Captcha',
#  'Captcha',
#  'Not found',
#  'Not found',
#  'Captcha',
#  'Captcha',
#  'Captcha',
#  'Not found',
#  'Not found',
#  'Captcha',
#  'Captcha',
#  'Captcha',
#  'Not found',
#  'Not found',
#  'Captcha',
#  'Captcha',
#  'Captcha',
#  'Not found',
#  'Not found',
#  'Captcha',
#  'Captcha',
#  'Captcha',
#  'Not found',
#  'Not found',
#  'Captcha',
#  'Captcha',
#  'Captcha',
#  'Not found',
#  'Not found',
#  'Captcha',
#  'Captcha',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Captcha',
#  'Captcha',
#  'Captcha',
#  'Not found',
#  'Not found',
#  'Captcha',
#  'Captcha',
#  'Captcha',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Captcha',
#  'Captcha',
#  'Not found',
#  'Not found',
#  'Captcha',
#  'Captcha',
#  'Captcha',
#  'Not found',
#  'Not found',
#  'Captcha',
#  'Captcha',
#  'Captcha',
#  'Not found',
#  'Not found',
#  'Captcha',
#  'Captcha',
#  'Captcha',
#  'Not found',
#  'Not found',
#  'Captcha',
#  'Captcha',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Captcha',
#  'Captcha',
#  'Captcha',
#  'Not found',
#  'Not found',
#  'Captcha',
#  'Captcha',
#  'Captcha',
#  {'product_title': "Fantasie über den Choral 'Ein feste Burg ist unser Gott' op. 27 für Orgel - Breitkopf Urtext (EB 8512)",
#   'product_image': 'https://images-eu.ssl-images-amazon.com/images/I/418j2w9CkKL._SY264_BO1,204,203,200_QL40_ML2_.jpg',
#   'product_price': '11,90',
#   'product_details': [{'Herausgeber': 'Breitkopf & Härtel (9. August 1990)'},
#    {'Sprache': 'Deutsch'},
#    {'Taschenbuch': '20 Seiten'},
#    {'ISBN-10': '000417805X'},
#    {'ISBN-13': '978-0004178059'}]},
#  {'product_title': 'Choralfantasie feste burg orgue',
#   'product_image': 'https://images-eu.ssl-images-amazon.com/images/I/418j2w9CkKL._SY291_BO1,204,203,200_QL40_ML2_.jpg',
#   'product_price': '26,09',
#   'product_details': [{'Éditeur': 'BREITKOPF (1 janvier 2000)'},
#    {'Langue': 'Allemand'},
#    {'Broché': '20 pages'},
#    {'ISBN-10': '000417805X'},
#    {'ISBN-13': '978-0004178059'},
#    {"Poids de l'article": '401 g'}]},
#  'Captcha',
#  'Captcha',
#  'Captcha',
#  'Not found',
#  'Not found',
#  'Captcha',
#  'Captcha',
#  'Captcha',
#  'Not found',
#  'Not found',
#  'Captcha',
#  'Captcha',
#  'Captcha',
#  'Not found',
#  'Not found',
#  'Captcha',
#  'Captcha',
#  'Captcha',
#  'Not found',
#  'Not found',
#  'Captcha',
#  'Captcha',
#  'Captcha',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Captcha',
#  'Captcha',
#  'Not found',
#  'Not found',
#  'Captcha',
#  'Captcha',
#  'Captcha',
#  'Not found',
#  'Not found',
#  'Captcha',
#  'Captcha',
#  'Captcha',
#  'Not found',
#  'Not found',
#  'Captcha',
#  'Captcha',
#  'Captcha',
#  'Not found',
#  'Not found',
#  'Captcha',
#  'Captcha',
#  'Captcha',
#  'Not found',
#  'Not found',
#  'Captcha',
#  'Captcha',
#  'Captcha',
#  'Not found',
#  'Not found',
#  'Captcha',
#  'Captcha',
#  'Captcha',
#  {'product_title': "L'ARLESIENNE-SUITE NR. 2 ORCHESTRE",
#   'product_image': 'https://images-eu.ssl-images-amazon.com/images/I/41ELX18MMVL._SX198_BO1,204,203,200_QL40_ML2_.jpg',
#   'product_price': '56,34',
#   'product_details': [{'Herausgeber': 'BREITKOPF (1. Januar 2000)'},
#    {'Sprache': 'Französisch'},
#    {'ISBN-10': '000420736X'},
#    {'ISBN-13': '979-0004207369'}]},
#  {'product_title': "L'arlesienne-suite nr. 2 orchestre",
#   'product_image': 'https://images-eu.ssl-images-amazon.com/images/I/41ELX18MMVL._SX218_BO1,204,203,200_QL40_ML2_.jpg',
#   'product_price': '52,14',
#   'product_details': [{'Éditeur': 'BREITKOPF (1 janvier 2000)'},
#    {'Langue': 'Français'},
#    {'ISBN-10': '000420736X'},
#    {'ISBN-13': '979-0004207369'},
#    {"Poids de l'article": '1 kg'}]},
#  'Captcha',
#  'Captcha',
#  'Captcha',
#  'Not found',
#  'Not found',
#  'Captcha',
#  'Captcha',
#  'Captcha',
#  'Not found',
#  'Not found',
#  'Captcha',
#  'Captcha',
#  'Captcha',
#  'Not found',
#  {'product_title': 'EIN DEUTSCHES REQUIEM 2 KLAV',
#   'product_image': 'https://images-eu.ssl-images-amazon.com/images/I/41kvwEvPVpL._SX198_BO1,204,203,200_QL40_ML2_.jpg',
#   'product_price': '92,00',
#   'product_details': [{'Herausgeber': 'BREITKOPF (1. Januar 2000)'},
#    {'Sprache': 'Französisch'},
#    {'ISBN-10': '000421143X'},
#    {'ISBN-13': '979-0004211434'}]},
#  'Captcha',
#  'Captcha',
#  'Captcha',
#  'Not found',
#  'Not found',
#  'Captcha',
#  'Captcha',
#  'Captcha',
#  'Not found',
#  'Not found',
#  'Captcha',
#  'Captcha',
#  'Captcha',
#  'Not found',
#  'Not found',
#  'Captcha',
#  'Captcha',
#  'Captcha',
#  'Not found',
#  'Not found',
#  'Captcha',
#  'Captcha',
#  'Captcha',
#  'Not found',
#  'Not found',
#  'Captcha',
#  'Captcha',
#  'Captcha',
#  'Not found',
#  'Not found',
#  'Captcha',
#  'Captcha',
#  'Captcha',
#  'Not found',
#  'Not found',
#  'Captcha',
#  'Captcha',
#  'Captcha',
#  'Not found',
#  'Not found',
#  'Captcha',
#  'Captcha',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Captcha',
#  'Captcha',
#  'Captcha',
#  'Not found',
#  'Not found',
#  'Captcha',
#  'Captcha',
#  'Captcha',
#  'Not found',
#  'Not found',
#  'Captcha',
#  'Captcha',
#  'Captcha',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Captcha',
#  'Captcha',
#  'Not found',
#  'Not found',
#  'Captcha',
#  'Captcha',
#  'Captcha',
#  'Not found',
#  'Not found',
#  'Captcha',
#  'Captcha',
#  'Captcha',
#  'Not found',
#  'Not found',
#  'Captcha',
#  'Captcha',
#  'Captcha',
#  'Not found',
#  'Not found',
#  'Captcha',
#  'Captcha',
#  'Captcha',
#  'Not found',
#  'Not found',
#  'Captcha',
#  'Captcha',
#  'Captcha',
#  'Not found']

# %%
all_products_details

# %%
export_to_json(all_products_details)

# %%
import mysql.connector

# Saving data in MySQL database
# To run this in local:
#   - connect to your database
#   - create table using query:
#
#   CREATE TABLE products(
# 	    id INT NOT NULL PRIMARY KEY AUTO_INCREMENT,
#   	product_title TEXT NOT NULL,
#   	product_image TEXT NOT NULL,
#   	product_price VARCHAR(255) NOT NULL,
#   	product_detail TEXT NOT NULL
#   )
def export_to_mysql_database(list_of_details):
    my_db = mysql.connector.connect(
        host = "localhost",
        user = "sagar",
        password = "password",
        database = "Credicxo"
    )
    cur = my_db.cursor()
    for row in list_of_details:
        if type(row) is dict:
            print("this row is inserted")
            cur.execute("INSERT INTO products_details(product_title, product_image, product_price, product_detail) values(%s, %s, %s, %s)", (str(row.get("product_title")), str(row.get("product_image")), str(row.get("product_price")), str(row.get("product_details"))   ))
        else:
            print("no data available in row")
            continue
    my_db.commit()
    cur.close()
    return "done"

# %%
export_to_mysql_database(all_products_details)
# Out:
# no data available in row
# no data available in row
# this row is inserted
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# this row is inserted
# this row is inserted
# no data available in row
# no data available in row
# this row is inserted
# this row is inserted
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# this row is inserted
# this row is inserted
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# this row is inserted
# this row is inserted
# no data available in row
# no data available in row
# this row is inserted
# this row is inserted
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# this row is inserted
# this row is inserted
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# this row is inserted
# this row is inserted
# this row is inserted
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# this row is inserted
# this row is inserted
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# this row is inserted
# this row is inserted
# this row is inserted
# no data available in row
# no data available in row
# this row is inserted
# this row is inserted
# this row is inserted
# this row is inserted
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# this row is inserted
# this row is inserted
# this row is inserted
# this row is inserted
# this row is inserted
# this row is inserted
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# this row is inserted
# this row is inserted
# no data available in row
# no data available in row
# this row is inserted
# this row is inserted
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# this row is inserted
# this row is inserted
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# this row is inserted
# this row is inserted
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# this row is inserted
# this row is inserted
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# this row is inserted
# this row is inserted
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# this row is inserted
# this row is inserted
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# this row is inserted
# this row is inserted
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# this row is inserted
# this row is inserted
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# this row is inserted
# this row is inserted
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# this row is inserted
# this row is inserted
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# this row is inserted
# this row is inserted
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# this row is inserted
# this row is inserted
# this row is inserted
# this row is inserted
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# this row is inserted
# this row is inserted
# no data available in row
# this row is inserted
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# this row is inserted
# this row is inserted
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# this row is inserted
# this row is inserted
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# this row is inserted
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# this row is inserted
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# this row is inserted
# this row is inserted
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# this row is inserted
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# this row is inserted
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# this row is inserted
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# this row is inserted
# this row is inserted
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# this row is inserted
# this row is inserted
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# this row is inserted
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# no data available in row
# 'done'

# %%
all_products_details
# Out:
# ['Not found',
#  'Not found',
#  {'product_title': 'Old Spice Rasur Creme - 70 G (original) - Packung Von 2',
#   'product_image': 'https://images-eu.ssl-images-amazon.com/images/I/41xHbjdSXJL._SY300_SX300_QL70_ML2_.jpg',
#   'product_price': '8,00',
#   'product_details': [{'Item-Paket Dimensionen L x b x H': '18.3 x 6.7 x 3.9 cm'},
#    {'Paketgewicht': '0.18 Kilogramm'},
#    {'Nettogewicht des Einzelartikels': '0.15 Pfund'},
#    {'Hersteller': 'Old Spice'},
#    {'Marke': 'Old Spice'},
#    {'Modellnummer': 'SG_000004458X_US'},
#    {'Verpackungsabmessungen': '18.29 x 6.71 x 3.91 cm; 68.04 Gramm'},
#    {'ASIN': '000004458X'}]},
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  {'product_title': 'Short Story: Violoncello und Klavier. (Cello-Bibliothek)',
#   'product_image': 'https://images-eu.ssl-images-amazon.com/images/I/41zw0783tpL._SX198_BO1,204,203,200_QL40_ML2_.jpg',
#   'product_price': '5,95',
#   'product_details': [{'Herausgeber': 'SCHOTT MUSIC GmbH & Co KG, Mainz (6. Februar 1986)'},
#    {'Sprache': 'Französisch'},
#    {'Musiknoten': '10 Seiten'},
#    {'ISBN-10': '000101742X'},
#    {'ISBN-13': '978-0001017429'}]},
#  {'product_title': 'Short story (dushkin/hegyi) violon',
#   'product_image': 'https://images-eu.ssl-images-amazon.com/images/I/41zw0783tpL._SX218_BO1,204,203,200_QL40_ML2_.jpg',
#   'product_price': '22,88',
#   'product_details': [{'Éditeur': 'SCHOTT (1 janvier 2000)'},
#    {'Langue': 'Français'},
#    {'ISBN-10': '000101742X'},
#    {'ISBN-13': '978-0001017429'},
#    {"Poids de l'article": '601 g'}]},
#  'Not found',
#  'Not found',
#  {'product_title': 'Concerto grosso g-Moll: Weihnachtskonzert. op. 6/8. 2 Violinen, Violoncello, Streichorchester und Cembalo. Partitur. (Concertino)',
#   'product_image': 'https://images-eu.ssl-images-amazon.com/images/I/51sNFyf2t6L._SX198_BO1,204,203,200_QL40_ML2_.jpg',
#   'product_price': '18,00',
#   'product_details': [{'Herausgeber': 'SCHOTT MUSIC GmbH & Co KG, Mainz (24. Februar 1984)'},
#    {'Sprache': 'Französisch'},
#    {'Musiknoten': '30 Seiten'},
#    {'ISBN-10': '000102163X'},
#    {'ISBN-13': '978-0001021631'}]},
#  {'product_title': 'Concerto grosso 8 g opus 6 partitu',
#   'product_image': 'https://images-eu.ssl-images-amazon.com/images/I/51sNFyf2t6L._SX218_BO1,204,203,200_QL40_ML2_.jpg',
#   'product_price': '30,99',
#   'product_details': [{'Éditeur': 'SCHOTT (1 janvier 2000)'},
#    {'Langue': 'Français'},
#    {'ISBN-10': '000102163X'},
#    {'ISBN-13': '978-0001021631'},
#    {"Poids de l'article": '358 g'}]},
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  {'product_title': 'Concertino B-Dur: Violine und Orchester. Klavierauszug mit Solostimme. (Edition Schott)',
#   'product_image': 'https://images-eu.ssl-images-amazon.com/images/I/41HnYQBk7PL._SX198_BO1,204,203,200_QL40_ML2_.jpg',
#   'product_price': '19,50',
#   'product_details': [{'Herausgeber': 'SCHOTT MUSIC GmbH & Co KG, Mainz (18. Januar 1980)'},
#    {'Sprache': 'Französisch'},
#    {'Musiknoten': '28 Seiten'},
#    {'ISBN-10': '000103863X'},
#    {'ISBN-13': '979-0001038638'}]},
#  {'product_title': 'Concertino bes violon',
#   'product_image': 'https://images-eu.ssl-images-amazon.com/images/I/41HnYQBk7PL._SX218_BO1,204,203,200_QL40_ML2_.jpg',
#   'product_price': '14,69',
#   'product_details': [{'Éditeur': 'SCHOTT (1 janvier 2000)'},
#    {'Langue': 'Français'},
#    {'ISBN-10': '000103863X'},
#    {'ISBN-13': '979-0001038638'},
#    {"Poids de l'article": '701 g'}]},
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  {'product_title': 'Concerto in E flat "Dumbarton Oaks": für Kammerorchester. Kammerorchester. Studienpartitur. (Musik unserer Zeit)',
#   'product_image': 'https://images-eu.ssl-images-amazon.com/images/I/41fgZjPnmCL._SY264_BO1,204,203,200_QL40_ML2_.jpg',
#   'product_price': '18,00',
#   'product_details': [{'Herausgeber': 'SCHOTT MUSIC GmbH & Co KG, Mainz; Das exakte Erscheinungsdatum ist leider unbekannt Edition (19. Juli 1984)'},
#    {'Sprache': 'Französisch'},
#    {'Musiknoten': '44 Seiten'},
#    {'ISBN-10': '000104317X'},
#    {'ISBN-13': '978-0001043176'}]},
#  {'product_title': "Concert es kammerorchester parti musique d'ensemble",
#   'product_image': 'https://images-eu.ssl-images-amazon.com/images/I/41fgZjPnmCL._SY291_BO1,204,203,200_QL40_ML2_.jpg',
#   'product_price': '27,08',
#   'product_details': [{'Éditeur': 'SCHOTT (1 janvier 2000)'},
#    {'Langue': 'Français'},
#    {'ISBN-10': '000104317X'},
#    {'ISBN-13': '978-0001043176'},
#    {"Poids de l'article": '601 g'}]},
#  'Not found',
#  'Not found',
#  {'product_title': 'Musik für Kinder: Im Fünftonraum. Vol. 1. Singstimme, Blockflöte und Schlagzeug. Sing- und Spielpartitur. (Orff-Schulwerk)',
#   'product_image': 'https://images-eu.ssl-images-amazon.com/images/I/419-3yqvVML._SX198_BO1,204,203,200_QL40_ML2_.jpg',
#   'product_price': '22,00',
#   'product_details': [{'Herausgeber': 'SCHOTT MUSIC GmbH & Co KG, Mainz (21. April 1980)'},
#    {'Sprache': 'Deutsch'},
#    {'Musiknoten': '187 Seiten'},
#    {'ISBN-10': '000104348X'},
#    {'ISBN-13': '978-0001043480'}]},
#  {'product_title': 'Schulwerk vol. 1 (ted.) (orff/keetman)',
#   'product_image': 'https://images-eu.ssl-images-amazon.com/images/I/419-3yqvVML._SX218_BO1,204,203,200_QL40_ML2_.jpg',
#   'product_price': '',
#   'product_details': [{'Éditeur': 'SCHOTT (1 janvier 2000)'},
#    {'Langue': 'Allemand'},
#    {'ISBN-10': '000104348X'},
#    {'ISBN-13': '978-0001043480'},
#    {"Poids de l'article": '701 g'}]},
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  {'product_title': '5 antike Oden: nach Gedichten von Sappho. op. 57. mittlere Frauenstimme, Viola und Klavier. mittel. Stimmensatz. (Edition Schott)',
#   'product_image': 'https://images-eu.ssl-images-amazon.com/images/I/41uGG66YO-L._SX198_BO1,204,203,200_QL40_ML2_.jpg',
#   'product_price': '32,00',
#   'product_details': [{'Herausgeber': 'SCHOTT MUSIC GmbH & Co KG, Mainz (7. Mai 1985)'},
#    {'Sprache': 'Deutsch'},
#    {'Musiknoten': '32 Seiten'},
#    {'ISBN-10': '000104396X'},
#    {'ISBN-13': '978-0001043961'}]},
#  {'product_title': 'Funf antike oden op. 57 -ensemble de partitions',
#   'product_image': 'https://images-eu.ssl-images-amazon.com/images/I/41uGG66YO-L._SX218_BO1,204,203,200_QL40_ML2_.jpg',
#   'product_price': '39,76',
#   'product_details': [{'Éditeur': 'SCHOTT (1 janvier 1985)'},
#    {'Langue': 'Allemand'},
#    {'ISBN-10': '000104396X'},
#    {'ISBN-13': '978-0001043961'},
#    {"Poids de l'article": '1 kg'}]},
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  {'product_title': 'Etuden 1 & 2 orgue',
#   'product_image': 'https://images-na.ssl-images-amazon.com/images/I/31+SH2b7VAL._SX258_BO1,204,203,200_.jpg',
#   'product_price': '31,19',
#   'product_details': [{'Editorial': 'SCHOTT (1 enero 2000)'},
#    {'Idioma': 'Francés'},
#    {'ISBN-10': '000106875X'},
#    {'ISBN-13': '978-0001068759'},
#    {'Peso del producto': '701 g'}]},
#  {'product_title': 'Etuden 1 & 2 orgue',
#   'product_image': 'https://images-na.ssl-images-amazon.com/images/I/31+SH2b7VAL._SX258_BO1,204,203,200_.jpg',
#   'product_price': '31,19',
#   'product_details': [{'Éditeur': 'SCHOTT (1 janvier 2000)'},
#    {'Langue': 'Français'},
#    {'ISBN-10': '000106875X'},
#    {'ISBN-13': '978-0001068759'},
#    {"Poids de l'article": '701 g'}]},
#  {'product_title': 'Etuden 1 & 2 orgue: Orgel.',
#   'product_image': 'https://images-na.ssl-images-amazon.com/images/I/31+SH2b7VAL._SX258_BO1,204,203,200_.jpg',
#   'product_price': '31,19',
#   'product_details': [{'Editore': 'SCHOTT (1 gennaio 2000)'},
#    {'Lingua': 'Francese'},
#    {'Spartito musicale': '12 pagine'},
#    {'ISBN-10': '000106875X'},
#    {'ISBN-13': '978-0001068759'},
#    {'Peso articolo': '701 g'}]},
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  {'product_title': 'Sämtliche Lieder mit Klavierbegleitung: mit Anhang: Frühe Lieder und Fragmente. Band 2. Singstimme und Klavier. (Edition Schott, Band 2)',
#   'product_image': 'https://images-eu.ssl-images-amazon.com/images/I/41K3KHLZHNL._SX198_BO1,204,203,200_QL40_ML2_.jpg',
#   'product_price': '',
#   'product_details': [{'Herausgeber': 'SCHOTT MUSIC GmbH & Co KG, Mainz; 2. Auflage 2008 (25. Mai 1983)'},
#    {'Sprache': 'Deutsch'},
#    {'Musiknoten': '288 Seiten'},
#    {'ISBN-10': '000107119X'},
#    {'ISBN-13': '979-0001071192'}]},
#  {'product_title': 'Complete songs with piano accompaniment band 2 chant',
#   'product_image': 'https://images-eu.ssl-images-amazon.com/images/I/41K3KHLZHNL._SX218_BO1,204,203,200_QL40_ML2_.jpg',
#   'product_price': '',
#   'product_details': [{'Éditeur': 'SCHOTT (1 janvier 1983)'},
#    {'Langue': 'Allemand'},
#    {'ISBN-10': '000107119X'},
#    {'ISBN-13': '979-0001071192'},
#    {"Poids de l'article": '1.5 kg'}]},
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  {'product_title': 'Orchester-Probespiel Kontrabass: Sammlung wichtiger Passagen aus der Opern- und Konzertliteratur. Kontrabass.',
#   'product_image': 'https://images-eu.ssl-images-amazon.com/images/I/61OVNlClEDL._SX198_BO1,204,203,200_QL40_ML2_.jpg',
#   'product_price': '26,00',
#   'product_details': [{'Herausgeber': 'SCHOTT MUSIC GmbH & Co KG, Mainz; 2. Auflage 2008 (29. Juni 1992)'},
#    {'Sprache': 'Französisch'},
#    {'Musiknoten': '62 Seiten'},
#    {'ISBN-10': '000108142X'},
#    {'ISBN-13': '979-0001081429'},
#    {'Abmessungen': '20 x 14 x 4 cm'}]},
#  {'product_title': 'Spielbuch orchestre',
#   'product_image': 'https://images-na.ssl-images-amazon.com/images/I/61OVNlClEDL._SX198_BO1,204,203,200_QL40_ML2_.jpg',
#   'product_price': '25,78',
#   'product_details': [{'Editorial': 'SCHOTT (1 enero 2000)'},
#    {'Idioma': 'Francés'},
#    {'ISBN-10': '000108142X'},
#    {'ISBN-13': '979-0001081429'},
#    {'Peso del producto': '801 g'},
#    {'Dimensiones': '20 x 14 x 4 cm'}]},
#  {'product_title': 'Spielbuch orchestre',
#   'product_image': 'https://images-eu.ssl-images-amazon.com/images/I/61OVNlClEDL._SX218_BO1,204,203,200_QL40_ML2_.jpg',
#   'product_price': '33,43',
#   'product_details': [{'Éditeur': 'SCHOTT (1 janvier 2000)'},
#    {'Langue': 'Français'},
#    {'Partition': '62 pages'},
#    {'ISBN-10': '000108142X'},
#    {'ISBN-13': '979-0001081429'},
#    {"Poids de l'article": '801 g'},
#    {'Dimensions': '20 x 14 x 4 cm'}]},
#  'Not found',
#  'Not found',
#  {'product_title': 'Wir hören und spielen: Ein Weg zum absoluten Gehör. Band 3. Klavier.',
#   'product_image': 'https://images-eu.ssl-images-amazon.com/images/I/51d3H5bMOmL._SX198_BO1,204,203,200_QL40_ML2_.jpg',
#   'product_price': '',
#   'product_details': [{'Herausgeber': 'SCHOTT MUSIC GmbH & Co KG, Mainz (17. Januar 1994)'},
#    {'Sprache': 'Deutsch'},
#    {'Musiknoten': '136 Seiten'},
#    {'ISBN-10': '000108173X'},
#    {'ISBN-13': '978-0001081734'}]},
#  {'product_title': 'Wir horen und spielen band 3 piano',
#   'product_image': 'https://images-eu.ssl-images-amazon.com/images/I/51d3H5bMOmL._SX218_BO1,204,203,200_QL40_ML2_.jpg',
#   'product_price': '',
#   'product_details': [{'Éditeur': 'SCHOTT (1 janvier 1994)'},
#    {'Langue': 'Allemand'},
#    {'ISBN-10': '000108173X'},
#    {'ISBN-13': '978-0001081734'},
#    {"Poids de l'article": '1.1 kg'}]},
#  {'product_title': 'Arien(2) (grand macabre) 2e akte',
#   'product_image': 'https://images-eu.ssl-images-amazon.com/images/I/41usGis9EJL._SX218_BO1,204,203,200_QL40_ML2_.jpg',
#   'product_price': '33,96',
#   'product_details': [{'Éditeur': 'SCHOTT (1 janvier 2000)'},
#    {'Langue': 'Français'},
#    {'ISBN-10': '000108299X'},
#    {'ISBN-13': '978-0001082991'},
#    {"Poids de l'article": '801 g'}]},
#  {'product_title': 'Arien(2) (grand macabre) 2e akte',
#   'product_image': 'https://images-eu.ssl-images-amazon.com/images/I/41usGis9EJL._SX198_BO1,204,203,200_QL40_ML2_.jpg',
#   'product_price': '10,20',
#   'product_details': [{'Editore': 'SCHOTT (1 gennaio 2000)'},
#    {'Lingua': 'Francese'},
#    {'Spartito musicale': '32 pagine'},
#    {'ISBN-10': '000108299X'},
#    {'ISBN-13': '978-0001082991'},
#    {'Peso articolo': '801 g'}]},
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  {'product_title': 'Fantasie c piano',
#   'product_image': 'https://images-eu.ssl-images-amazon.com/images/I/41qQkCHj52L._SX218_BO1,204,203,200_QL40_ML2_.jpg',
#   'product_price': '9,03',
#   'product_details': [{'Éditeur': 'SCHOTT (1 janvier 2000)'},
#    {'Langue': 'Français'},
#    {'ISBN-10': '000108657X'},
#    {'ISBN-13': '978-0001086579'},
#    {"Poids de l'article": '201 g'},
#    {'Dimensions': '20 x 14 x 4 cm'}]},
#  {'product_title': 'Fantasie c piano',
#   'product_image': 'https://images-eu.ssl-images-amazon.com/images/I/41qQkCHj52L._SX198_BO1,204,203,200_QL40_ML2_.jpg',
#   'product_price': '9,03',
#   'product_details': [{'Editore': 'SCHOTT (1 gennaio 2000)'},
#    {'Lingua': 'Francese'},
#    {'Spartito musicale': '12 pagine'},
#    {'ISBN-10': '000108657X'},
#    {'ISBN-13': '978-0001086579'},
#    {'Peso articolo': '201 g'},
#    {'Dimensioni': '20 x 14 x 4 cm'}]},
#  {'product_title': 'Le Coucou: Rondeau. Klavier. (Edition Schott Einzelausgabe)',
#   'product_image': 'https://images-eu.ssl-images-amazon.com/images/I/41am5Cllb9L._SX198_BO1,204,203,200_QL40_ML2_.jpg',
#   'product_price': '1,20',
#   'product_details': [{'Herausgeber': 'SCHOTT MUSIC GmbH & Co KG, Mainz (6. Januar 1984)'},
#    {'Sprache': 'Französisch'},
#    {'Musiknoten': '8 Seiten'},
#    {'ISBN-10': '000108660X'},
#    {'ISBN-13': '978-0001086609'}]},
#  {'product_title': 'Coucou piano',
#   'product_image': 'https://images-eu.ssl-images-amazon.com/images/I/41am5Cllb9L._SX218_BO1,204,203,200_QL40_ML2_.jpg',
#   'product_price': '17,80',
#   'product_details': [{'Éditeur': 'SCHOTT (1 janvier 2000)'},
#    {'Langue': 'Français'},
#    {'ISBN-10': '000108660X'},
#    {'ISBN-13': '978-0001086609'},
#    {"Poids de l'article": '201 g'}]},
#  {'product_title': 'Adelaide: op. 46. mittlere Singstimme und Klavier. (Edition Schott Einzelausgabe)',
#   'product_image': 'https://images-eu.ssl-images-amazon.com/images/I/41zo5m7iCzL._SX198_BO1,204,203,200_QL40_ML2_.jpg',
#   'product_price': '6,50',
#   'product_details': [{'Herausgeber': 'SCHOTT MUSIC GmbH & Co KG, Mainz (30. Juni 1976)'},
#    {'Sprache': 'Deutsch, Englisch, Französisch'},
#    {'Musiknoten': '12 Seiten'},
#    {'ISBN-10': '000108688X'},
#    {'ISBN-13': '978-0001086883'}]},
#  {'product_title': 'Adelaide op.46',
#   'product_image': 'https://images-eu.ssl-images-amazon.com/images/I/41zo5m7iCzL._SX218_BO1,204,203,200_QL40_ML2_.jpg',
#   'product_price': '12,86',
#   'product_details': [{'Éditeur': 'SCHOTT (1 janvier 2000)'},
#    {'Langue': 'Allemand, Anglais, Français'},
#    {'ISBN-10': '000108688X'},
#    {'ISBN-13': '978-0001086883'},
#    {"Poids de l'article": '201 g'}]},
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  {'product_title': 'Cavatine: op. 85/3. Violine (Violoncello) und Klavier. (Edition Schott Einzelausgabe)',
#   'product_image': 'https://images-eu.ssl-images-amazon.com/images/I/410JKNeHjbL._SX198_BO1,204,203,200_QL40_ML2_.jpg',
#   'product_price': '4,50',
#   'product_details': [{'Herausgeber': 'SCHOTT MUSIC GmbH & Co KG, Mainz (15. März 1979)'},
#    {'Sprache': 'Französisch'},
#    {'Musiknoten': '8 Seiten'},
#    {'ISBN-10': '000108898X'},
#    {'ISBN-13': '979-0001088985'}]},
#  {'product_title': 'Cavatine opus 85/3 violon',
#   'product_image': 'https://images-eu.ssl-images-amazon.com/images/I/410JKNeHjbL._SX218_BO1,204,203,200_QL40_ML2_.jpg',
#   'product_price': '10,12',
#   'product_details': [{'Éditeur': 'SCHOTT (1 janvier 2000)'},
#    {'Langue': 'Français'},
#    {'ISBN-10': '000108898X'},
#    {'ISBN-13': '979-0001088985'},
#    {"Poids de l'article": '201 g'}]},
#  'Not found',
#  'Not found',
#  {'product_title': 'Gnomenreigen: Konzert-Etüde. Klavier. (Edition Schott Einzelausgabe)',
#   'product_image': 'https://images-eu.ssl-images-amazon.com/images/I/41A1-6T49fL._SX198_BO1,204,203,200_QL40_ML2_.jpg',
#   'product_price': '5,50',
#   'product_details': [{'Herausgeber': 'SCHOTT MUSIC GmbH & Co KG, Mainz (15. März 1978)'},
#    {'Sprache': 'Französisch'},
#    {'Musiknoten': '12 Seiten'},
#    {'ISBN-10': '000108917X'},
#    {'ISBN-13': '978-0001089174'}]},
#  {'product_title': 'Gnomenreigen piano',
#   'product_image': 'https://images-eu.ssl-images-amazon.com/images/I/41A1-6T49fL._SX218_BO1,204,203,200_QL40_ML2_.jpg',
#   'product_price': '10,23',
#   'product_details': [{'Éditeur': 'SCHOTT (1 janvier 2000)'},
#    {'Langue': 'Français'},
#    {'ISBN-10': '000108917X'},
#    {'ISBN-13': '978-0001089174'},
#    {"Poids de l'article": '201 g'}]},
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  {'product_title': 'Moto perpetuo: op. 11. Violine und Klavier. (Edition Schott Einzelausgabe)',
#   'product_image': 'https://images-eu.ssl-images-amazon.com/images/I/41L-o9AvBSL._SX198_BO1,204,203,200_QL40_ML2_.jpg',
#   'product_price': '6,50',
#   'product_details': [{'Herausgeber': 'SCHOTT MUSIC GmbH & Co KG, Mainz (26. August 1985)'},
#    {'Sprache': 'Französisch'},
#    {'Musiknoten': '16 Seiten'},
#    {'ISBN-10': '000109212X'},
#    {'ISBN-13': '978-0001092129'}]},
#  {'product_title': 'Moto perpetuo violon',
#   'product_image': 'https://images-eu.ssl-images-amazon.com/images/I/41L-o9AvBSL._SX218_BO1,204,203,200_QL40_ML2_.jpg',
#   'product_price': '10,60',
#   'product_details': [{'Éditeur': 'SCHOTT (1 janvier 2000)'},
#    {'Langue': 'Français'},
#    {'ISBN-10': '000109212X'},
#    {'ISBN-13': '978-0001092129'},
#    {"Poids de l'article": '201 g'}]},
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  {'product_title': 'Happy Birthday: Humoristische Variationen über ein Geburtstagslied. Klavier 4-händig. (Edition Schott Einzelausgabe)',
#   'product_image': 'https://images-eu.ssl-images-amazon.com/images/I/41wLZGTLuGL._SX198_BO1,204,203,200_QL40_ML2_.jpg',
#   'product_price': '6,50',
#   'product_details': [{'Herausgeber': 'SCHOTT MUSIC GmbH & Co KG, Mainz (13. Januar 1988)'},
#    {'Sprache': 'Französisch'},
#    {'Musiknoten': '16 Seiten'},
#    {'ISBN-10': '000109257X'},
#    {'ISBN-13': '978-0001092570'}]},
#  {'product_title': 'Happy birthday piano',
#   'product_image': 'https://images-eu.ssl-images-amazon.com/images/I/41wLZGTLuGL._SX218_BO1,204,203,200_QL40_ML2_.jpg',
#   'product_price': '18,86',
#   'product_details': [{'Éditeur': 'SCHOTT (1 janvier 2000)'},
#    {'Langue': 'Français'},
#    {'ISBN-10': '000109257X'},
#    {'ISBN-13': '978-0001092570'},
#    {"Poids de l'article": '201 g'}]},
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  {'product_title': '6 Duos: op. 1. 2 Flöten. Spielpartitur. (Edition Schott)',
#   'product_image': 'https://images-eu.ssl-images-amazon.com/images/I/41yNWRfXqDL._SX198_BO1,204,203,200_QL40_ML2_.jpg',
#   'product_price': '24,50',
#   'product_details': [{'Herausgeber': 'SCHOTT MUSIC GmbH & Co KG, Mainz (8. März 1994)'},
#    {'Sprache': 'Französisch'},
#    {'Musiknoten': '56 Seiten'},
#    {'ISBN-10': '000109453X'},
#    {'ISBN-13': '978-0001094536'}]},
#  {'product_title': 'Duos(6) opus 1 flute traversiere',
#   'product_image': 'https://images-eu.ssl-images-amazon.com/images/I/41yNWRfXqDL._SX218_BO1,204,203,200_QL40_ML2_.jpg',
#   'product_price': '32,82',
#   'product_details': [{'Éditeur': 'SCHOTT (1 janvier 2000)'},
#    {'Langue': 'Français'},
#    {'ISBN-10': '000109453X'},
#    {'ISBN-13': '978-0001094536'},
#    {"Poids de l'article": '701 g'}]},
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  {'product_title': 'Csárdás-Kompositionen: Klarinette und Klavier. (Edition Schott)',
#   'product_image': 'https://images-eu.ssl-images-amazon.com/images/I/41vzotqLOgL._SX198_BO1,204,203,200_QL40_ML2_.jpg',
#   'product_price': '16,00',
#   'product_details': [{'Herausgeber': 'SCHOTT MUSIC GmbH & Co KG, Mainz (3. Oktober 1988)'},
#    {'Sprache': 'Französisch'},
#    {'Musiknoten': '31 Seiten'},
#    {'ISBN-10': '000109825X'},
#    {'ISBN-13': '979-0001098250'}]},
#  {'product_title': 'Csardas-kompositionen clarinette',
#   'product_image': 'https://images-eu.ssl-images-amazon.com/images/I/41vzotqLOgL._SX218_BO1,204,203,200_QL40_ML2_.jpg',
#   'product_price': '26,26',
#   'product_details': [{'Éditeur': 'SCHOTT (1 janvier 2000)'},
#    {'Langue': 'Français'},
#    {'ISBN-10': '000109825X'},
#    {'ISBN-13': '979-0001098250'},
#    {"Poids de l'article": '120 g'}]},
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  {'product_title': 'Sérénade espagnole: Violine und Klavier. (Edition Schott, Nr. 26)',
#   'product_image': 'https://images-eu.ssl-images-amazon.com/images/I/419YG5nPHEL._SX198_BO1,204,203,200_QL40_ML2_.jpg',
#   'product_price': '9,00',
#   'product_details': [{'Herausgeber': 'SCHOTT MUSIC GmbH & Co KG, Mainz (26. August 1985)'},
#    {'Sprache': 'Französisch'},
#    {'Musiknoten': '8 Seiten'},
#    {'ISBN-10': '000110733X'},
#    {'ISBN-13': '978-0001107335'}]},
#  {'product_title': 'Serenata spagnola (kreisler) violon',
#   'product_image': 'https://images-eu.ssl-images-amazon.com/images/I/419YG5nPHEL._SX218_BO1,204,203,200_QL40_ML2_.jpg',
#   'product_price': '14,77',
#   'product_details': [{'Éditeur': 'SCHOTT (1 janvier 2000)'},
#    {'Langue': 'Français'},
#    {'Partition': '7 pages'},
#    {'ISBN-10': '000110733X'},
#    {'ISBN-13': '978-0001107335'},
#    {"Poids de l'article": '401 g'}]},
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  {'product_title': 'Eingedunkelt: Neun Gedichte nach Paul Celan. Alt-Solo. Alt.',
#   'product_image': 'https://images-eu.ssl-images-amazon.com/images/I/41suSIrxOHL._SX198_BO1,204,203,200_QL40_ML2_.jpg',
#   'product_price': '18,00',
#   'product_details': [{'Herausgeber': 'SCHOTT MUSIC GmbH & Co KG, Mainz (22. Dezember 1995)'},
#    {'Sprache': 'Deutsch'},
#    {'Musiknoten': '16 Seiten'},
#    {'ISBN-10': '000111252X'},
#    {'ISBN-13': '979-0001112529'}]},
#  {'product_title': 'Eingedunkelt',
#   'product_image': 'https://images-eu.ssl-images-amazon.com/images/I/41suSIrxOHL._SX218_BO1,204,203,200_QL40_ML2_.jpg',
#   'product_price': '24,99',
#   'product_details': [{'Éditeur': 'SCHOTT (1 janvier 1995)'},
#    {'Langue': 'Allemand'},
#    {'ISBN-10': '000111252X'},
#    {'ISBN-13': '979-0001112529'},
#    {"Poids de l'article": '601 g'}]},
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  {'product_title': 'Viola Spaces: Contemporary Viola Studies. Band 1. Viola. (Essential Exercises, Band 1)',
#   'product_image': 'https://images-eu.ssl-images-amazon.com/images/I/41Y-4h2wgsL._SX198_BO1,204,203,200_QL40_ML2_.jpg',
#   'product_price': '22,19',
#   'product_details': [{'Herausgeber': 'SCHOTT MUSIC GmbH & Co KG, Mainz (9. März 2009)'},
#    {'Sprache': 'Deutsch, Englisch'},
#    {'Musiknoten': '48 Seiten'},
#    {'ISBN-10': '000115687X'},
#    {'ISBN-13': '978-0001156876'}]},
#  {'product_title': 'Viola spaces vol. 1 alto',
#   'product_image': 'https://images-eu.ssl-images-amazon.com/images/I/41Y-4h2wgsL._SX218_BO1,204,203,200_QL40_ML2_.jpg',
#   'product_price': '48,56',
#   'product_details': [{'Éditeur': 'SCHOTT (1 janvier 2009)'},
#    {'Langue': 'Allemand, Anglais'},
#    {'ISBN-10': '000115687X'},
#    {'ISBN-13': '978-0001156876'},
#    {"Poids de l'article": '801 g'}]},
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  {'product_title': 'Klaviertrio G-Dur Hob XV:15 (EB 1131)',
#   'product_image': 'https://images-eu.ssl-images-amazon.com/images/I/41zx75efEBL._SX198_BO1,204,203,200_QL40_ML2_.jpg',
#   'product_price': '13,90',
#   'product_details': [{'Herausgeber': 'Breitkopf & Härtel (31. Mai 1966)'},
#    {'Sprache': 'Deutsch'},
#    {'Taschenbuch': '40 Seiten'},
#    {'ISBN-10': '000416041X'},
#    {'ISBN-13': '979-0004160411'}]},
#  {'product_title': 'Klavier-trio g-dur hob xv: 15',
#   'product_image': 'https://images-eu.ssl-images-amazon.com/images/I/41zx75efEBL._SX218_BO1,204,203,200_QL40_ML2_.jpg',
#   'product_price': '15,38',
#   'product_details': [{'Éditeur': 'BREITKOPF (1 janvier 2000)'},
#    {'Langue': 'Allemand'},
#    {'Broché': '40 pages'},
#    {'ISBN-10': '000416041X'},
#    {'ISBN-13': '979-0004160411'},
#    {"Poids de l'article": '401 g'}]},
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  {'product_title': 'VIOLINKONZERT 2 D-DUR KV 211',
#   'product_image': 'https://images-eu.ssl-images-amazon.com/images/I/51Qp-R83kUL._SX198_BO1,204,203,200_QL40_ML2_.jpg',
#   'product_price': '19,02',
#   'product_details': [{'Herausgeber': 'BREITKOPF (1. Januar 2000)'},
#    {'Sprache': 'Französisch'},
#    {'ISBN-10': '000416105X'},
#    {'ISBN-13': '978-0004161051'}]},
#  {'product_title': 'Violinkonzert 2 d-dur kv 211',
#   'product_image': 'https://images-eu.ssl-images-amazon.com/images/I/51Qp-R83kUL._SX218_BO1,204,203,200_QL40_ML2_.jpg',
#   'product_price': '19,99',
#   'product_details': [{'Éditeur': 'BREITKOPF (1 janvier 2000)'},
#    {'Langue': 'Français'},
#    {'ISBN-10': '000416105X'},
#    {'ISBN-13': '978-0004161051'},
#    {"Poids de l'article": '340 g'}]},
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  {'product_title': '2 divertimenti kv 252, kv 240',
#   'product_image': 'https://images-eu.ssl-images-amazon.com/images/I/41H73ri0GDL._SY291_BO1,204,203,200_QL40_ML2_.jpg',
#   'product_price': '22,37',
#   'product_details': [{'Éditeur': 'BREITKOPF (1 janvier 2000)'},
#    {'Langue': 'Allemand'},
#    {'Broché': '36 pages'},
#    {'ISBN-10': '000416198X'},
#    {'ISBN-13': '978-0004161983'},
#    {"Poids de l'article": '1 kg'}]},
#  {'product_title': '2 leichte Divertimenti für Violine (Oboe), Cello (Fagott) und Klavier - Es-dur KV 252 (240a) und B-dur KV 240 - Bearbeitung (EB 3810)',
#   'product_image': 'https://images-eu.ssl-images-amazon.com/images/I/41H73ri0GDL._SY264_BO1,204,203,200_QL40_ML2_.jpg',
#   'product_price': '22,37',
#   'product_details': [{'Editore': 'Breitkopf & Härtel (1 gennaio 2000)'},
#    {'Lingua': 'Tedesco'},
#    {'Copertina flessibile': '36 pagine'},
#    {'ISBN-10': '000416198X'},
#    {'ISBN-13': '978-0004161983'},
#    {'Peso articolo': '1 kg'}]},
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  {'product_title': "Il Re pastore KV 208 - L'amerò, sarò costante - Arie der Aminta - Ausgabe für Sorpan, Violine und Klavier (EB 5473)",
#   'product_image': 'https://images-eu.ssl-images-amazon.com/images/I/41YwjHe4wkL._SX198_BO1,204,203,200_QL40_ML2_.jpg',
#   'product_price': '7,90',
#   'product_details': [{'Herausgeber': 'Breitkopf & Härtel (5. November 1963)'},
#    {'Sprache': 'Deutsch'},
#    {'Musiknoten': '10 Seiten'},
#    {'ISBN-10': '000416413X'},
#    {'ISBN-13': '978-0004164137'}]},
#  {'product_title': "L'amero/dein bin ich kv 208",
#   'product_image': 'https://images-eu.ssl-images-amazon.com/images/I/41YwjHe4wkL._SX218_BO1,204,203,200_QL40_ML2_.jpg',
#   'product_price': '10,55',
#   'product_details': [{'Éditeur': 'BREITKOPF (1 janvier 2000)'},
#    {'Langue': 'Allemand'},
#    {'Partition': '10 pages'},
#    {'ISBN-10': '000416413X'},
#    {'ISBN-13': '978-0004164137'},
#    {"Poids de l'article": '201 g'}]},
#  {'product_title': 'Sonate op. 41 - Ausgabe für Fagott und Klavier (EB 5567)',
#   'product_image': 'https://images-eu.ssl-images-amazon.com/images/I/41aptNQZHrL._SX198_BO1,204,203,200_QL40_ML2_.jpg',
#   'product_price': '35,90',
#   'product_details': [{'Herausgeber': 'Breitkopf & Härtel (21. März 1961)'},
#    {'Sprache': 'Deutsch'},
#    {'Taschenbuch': '36 Seiten'},
#    {'ISBN-10': '000416444X'},
#    {'ISBN-13': '978-0004164441'}]},
#  {'product_title': 'Sonate op. 41 basson',
#   'product_image': 'https://images-eu.ssl-images-amazon.com/images/I/41aptNQZHrL._SX218_BO1,204,203,200_QL40_ML2_.jpg',
#   'product_price': '30,75',
#   'product_details': [{'Éditeur': 'BREITKOPF (1 janvier 2000)'},
#    {'Langue': 'Allemand'},
#    {'Broché': '36 pages'},
#    {'ISBN-10': '000416444X'},
#    {'ISBN-13': '978-0004164441'},
#    {"Poids de l'article": '140 g'}]},
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Captcha',
#  'Not found',
#  'Not found',
#  {'product_title': 'Quintett B-dur op. 34 - Breitkopf Urtext - Stimmensatz (EB 5830)',
#   'product_image': 'https://images-eu.ssl-images-amazon.com/images/I/41QN-6dasEL._SX198_BO1,204,203,200_QL40_ML2_.jpg',
#   'product_price': '25,90',
#   'product_details': [{'Herausgeber': 'Breitkopf & Härtel (29. April 1966)'},
#    {'Sprache': 'Deutsch'},
#    {'Taschenbuch': '68 Seiten'},
#    {'ISBN-10': '000416508X'},
#    {'ISBN-13': '978-0004165080'},
#    {'Abmessungen': '30.51 x 23.01 x 0.48 cm'}]},
#  {'product_title': 'Quintett b-dur op. 34 clarinette',
#   'product_image': 'https://images-eu.ssl-images-amazon.com/images/I/41QN-6dasEL._SX218_BO1,204,203,200_QL40_ML2_.jpg',
#   'product_price': '36,44',
#   'product_details': [{'Éditeur': 'BREITKOPF (1 janvier 2000)'},
#    {'Langue': 'Allemand'},
#    {'Broché': '68 pages'},
#    {'ISBN-10': '000416508X'},
#    {'ISBN-13': '978-0004165080'},
#    {"Poids de l'article": '500 g'},
#    {'Dimensions': '30.51 x 23.01 x 0.48 cm'}]},
#  'Captcha',
#  {'product_title': 'Sonate bes flute traversiere',
#   'product_image': 'https://images-eu.ssl-images-amazon.com/images/I/515ZbxjDfLL._SY291_BO1,204,203,200_QL40_ML2_.jpg',
#   'product_price': '20,96',
#   'product_details': [{'Éditeur': 'BREITKOPF (1 janvier 2000)'},
#    {'Langue': 'Allemand'},
#    {'Partition': '36 pages'},
#    {'ISBN-10': '000416511X'},
#    {'ISBN-13': '979-0004165119'},
#    {"Poids de l'article": '501 g'}]},
#  'Not found',
#  'Not found',
#  'Not found',
#  'Captcha',
#  'Not found',
#  'Captcha',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Captcha',
#  'Not found',
#  'Not found',
#  'Captcha',
#  'Captcha',
#  'Captcha',
#  {'product_title': 'Chaconne d-moll aus bwv 1004',
#   'product_image': 'https://images-eu.ssl-images-amazon.com/images/I/41lrIDbi75L._SY291_BO1,204,203,200_QL40_ML2_.jpg',
#   'product_price': '13,93',
#   'product_details': [{'Éditeur': 'BREITKOPF (1 janvier 2000)'},
#    {'Langue': 'Allemand'},
#    {'Partition': '16 pages'},
#    {'ISBN-10': '000416816X'},
#    {'ISBN-13': '978-0004168166'},
#    {"Poids de l'article": '401 g'}]},
#  {'product_title': 'Chaconne aus der Partita II d-moll BWV 1004 Bearbeitung für Cembalo (EB 6594)',
#   'product_image': 'https://images-eu.ssl-images-amazon.com/images/I/41lrIDbi75L._SY264_BO1,204,203,200_QL40_ML2_.jpg',
#   'product_price': '13,93',
#   'product_details': [{'Editore': 'Breitkopf & Härtel (1 gennaio 2000)'},
#    {'Lingua': 'Tedesco'},
#    {'Spartito musicale': '16 pagine'},
#    {'ISBN-10': '000416816X'},
#    {'ISBN-13': '978-0004168166'},
#    {'Peso articolo': '401 g'}]},
#  'Captcha',
#  'Captcha',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Captcha',
#  'Captcha',
#  'Captcha',
#  'Not found',
#  'Not found',
#  'Captcha',
#  'Captcha',
#  'Captcha',
#  'Not found',
#  'Not found',
#  'Captcha',
#  'Captcha',
#  'Captcha',
#  {'product_title': 'LITANIAE DE VENERABILI KV 243',
#   'product_image': 'https://images-na.ssl-images-amazon.com/images/I/414wyAfP+WL._SY344_BO1,204,203,200_.jpg',
#   'product_price': '15,40',
#   'product_details': [{'Herausgeber': 'BREITKOPF (1. Januar 2000)'},
#    {'Sprache': 'Französisch'},
#    {'ISBN-10': '000416976X'},
#    {'ISBN-13': '979-0004169766'}]},
#  {'product_title': 'Litaniae de venerabili kv 243',
#   'product_image': 'https://images-na.ssl-images-amazon.com/images/I/414wyAfP+WL._SY344_BO1,204,203,200_.jpg',
#   'product_price': '16,26',
#   'product_details': [{'Éditeur': 'BREITKOPF (1 janvier 2000)'},
#    {'Langue': 'Français'},
#    {'ISBN-10': '000416976X'},
#    {'ISBN-13': '979-0004169766'},
#    {"Poids de l'article": '501 g'}]},
#  'Captcha',
#  'Captcha',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Captcha',
#  'Captcha',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Captcha',
#  'Captcha',
#  'Captcha',
#  'Not found',
#  'Not found',
#  'Captcha',
#  'Captcha',
#  'Captcha',
#  'Not found',
#  'Not found',
#  'Captcha',
#  'Captcha',
#  'Captcha',
#  'Not found',
#  'Not found',
#  'Captcha',
#  'Captcha',
#  'Captcha',
#  'Not found',
#  'Not found',
#  'Captcha',
#  'Captcha',
#  'Captcha',
#  'Not found',
#  'Not found',
#  'Captcha',
#  'Captcha',
#  'Captcha',
#  'Not found',
#  'Not found',
#  'Captcha',
#  'Captcha',
#  'Captcha',
#  'Not found',
#  {'product_title': 'Kantate 52 Falsche Welt, Dir',
#   'product_image': 'https://images-eu.ssl-images-amazon.com/images/I/41mTrzyK76L._SY264_BO1,204,203,200_QL40_ML2_.jpg',
#   'product_price': '7,39',
#   'product_details': [{'Herausgeber': 'BREITKOPF; Klavierauszug Leipzig 1984 Edition (1. Januar 2000)'},
#    {'Sprache': 'Französisch'},
#    {'Musiknoten': '20 Seiten'},
#    {'ISBN-10': '000417206X'},
#    {'ISBN-13': '978-0004172064'}]},
#  'Captcha',
#  'Captcha',
#  'Captcha',
#  'Not found',
#  'Not found',
#  'Captcha',
#  'Captcha',
#  'Captcha',
#  'Not found',
#  'Not found',
#  'Captcha',
#  'Captcha',
#  'Captcha',
#  'Not found',
#  'Not found',
#  'Captcha',
#  'Captcha',
#  'Captcha',
#  'Not found',
#  {'product_title': 'Kantate 86 Wahrlich, Wahrlich',
#   'product_image': 'https://images-eu.ssl-images-amazon.com/images/I/41aWBN0BW1L._SY264_BO1,204,203,200_QL40_ML2_.jpg',
#   'product_price': '6,50',
#   'product_details': [{'Herausgeber': 'BREITKOPF; Klavierauszug Leipzig 1983 Edition (1. Januar 2000)'},
#    {'Sprache': 'Französisch'},
#    {'Taschenbuch': '20 Seiten'},
#    {'ISBN-10': '000417240X'},
#    {'ISBN-13': '979-0004172407'}]},
#  'Captcha',
#  'Captcha',
#  'Captcha',
#  'Not found',
#  'Not found',
#  'Captcha',
#  'Captcha',
#  'Captcha',
#  'Not found',
#  'Not found',
#  'Captcha',
#  'Captcha',
#  'Captcha',
#  'Not found',
#  'Not found',
#  'Captcha',
#  'Captcha',
#  'Captcha',
#  'Not found',
#  'Not found',
#  'Captcha',
#  'Captcha',
#  'Not found',
#  {'product_title': 'Kantate 114 Ach Lieben',
#   'product_image': 'https://images-eu.ssl-images-amazon.com/images/I/41mIiAzCWsL._SY264_BO1,204,203,200_QL40_ML2_.jpg',
#   'product_price': '8,50',
#   'product_details': [{'Herausgeber': 'BREITKOPF; Klavierauszug Leipzig 1985 Edition (1. Januar 2000)'},
#    {'Sprache': 'Französisch'},
#    {'Taschenbuch': '28 Seiten'},
#    {'ISBN-10': '000417268X'},
#    {'ISBN-13': '979-0004172681'}]},
#  {'product_title': 'Kantate 114 ach lieben',
#   'product_image': 'https://images-eu.ssl-images-amazon.com/images/I/41mIiAzCWsL._SY291_BO1,204,203,200_QL40_ML2_.jpg',
#   'product_price': '9,00',
#   'product_details': [{'Éditeur': 'BREITKOPF (1 janvier 2000)'},
#    {'Langue': 'Français'},
#    {'ISBN-10': '000417268X'},
#    {'ISBN-13': '979-0004172681'},
#    {"Poids de l'article": '201 g'}]},
#  'Captcha',
#  'Captcha',
#  'Captcha',
#  'Not found',
#  {'product_title': 'Kantate 117 Sie Lob Und Ehr',
#   'product_image': 'https://images-eu.ssl-images-amazon.com/images/I/41hlFmvlMsL._SY264_BO1,204,203,200_QL40_ML2_.jpg',
#   'product_price': '9,15',
#   'product_details': [{'Herausgeber': 'BREITKOPF; Klavierauszug deutsch/englisch Edition (1. Januar 2000)'},
#    {'Sprache': 'Französisch'},
#    {'Broschüre': '28 Seiten'},
#    {'ISBN-10': '000417271X'},
#    {'ISBN-13': '978-0004172712'}]},
#  'Captcha',
#  'Captcha',
#  'Captcha',
#  'Not found',
#  'Not found',
#  'Captcha',
#  'Captcha',
#  'Captcha',
#  'Not found',
#  'Not found',
#  'Captcha',
#  'Captcha',
#  'Captcha',
#  'Not found',
#  'Not found',
#  'Captcha',
#  'Captcha',
#  'Captcha',
#  'Not found',
#  'Not found',
#  'Captcha',
#  'Captcha',
#  'Captcha',
#  'Not found',
#  'Not found',
#  'Captcha',
#  'Captcha',
#  'Captcha',
#  'Not found',
#  {'product_title': 'Bach, Kantate 164, Ihr, die ihr euch von Christo nennet',
#   'product_image': 'https://images-na.ssl-images-amazon.com/images/I/41+g+QbpBFL._SX258_BO1,204,203,200_.jpg',
#   'product_price': '7,39',
#   'product_details': [{'Herausgeber': 'BREITKOPF; Klavierauszug Leipzig 1986 Edition (1. Januar 2000)'},
#    {'Sprache': 'Französisch'},
#    {'Taschenbuch': '20 Seiten'},
#    {'ISBN-10': '000417318X'},
#    {'ISBN-13': '979-0004173183'}]},
#  'Captcha',
#  'Captcha',
#  'Captcha',
#  'Not found',
#  'Not found',
#  'Captcha',
#  'Captcha',
#  'Captcha',
#  'Not found',
#  'Not found',
#  'Captcha',
#  'Captcha',
#  'Captcha',
#  'Not found',
#  'Not found',
#  'Captcha',
#  'Captcha',
#  'Captcha',
#  {'product_title': 'Kantate 181 leichtgesinnte',
#   'product_image': 'https://images-eu.ssl-images-amazon.com/images/I/31D4bTOuJaL._SY291_BO1,204,203,200_QL40_ML2_.jpg',
#   'product_price': '2,68',
#   'product_details': [{'Éditeur': 'BREITKOPF (1 janvier 2000)'},
#    {'Langue': 'Français'},
#    {'ISBN-10': '000417335X'},
#    {'ISBN-13': '978-0004173351'},
#    {"Poids de l'article": '201 g'}]},
#  'Not found',
#  'Captcha',
#  'Not found',
#  'Captcha',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Captcha',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Captcha',
#  'Captcha',
#  'Captcha',
#  'Not found',
#  'Not found',
#  'Captcha',
#  'Captcha',
#  'Captcha',
#  'Not found',
#  'Not found',
#  'Captcha',
#  'Captcha',
#  'Captcha',
#  'Not found',
#  'Not found',
#  'Captcha',
#  'Captcha',
#  'Captcha',
#  'Not found',
#  'Not found',
#  'Captcha',
#  'Captcha',
#  'Captcha',
#  'Not found',
#  'Not found',
#  'Captcha',
#  'Captcha',
#  'Captcha',
#  'Not found',
#  'Not found',
#  'Captcha',
#  'Captcha',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Captcha',
#  'Captcha',
#  'Captcha',
#  'Not found',
#  'Not found',
#  'Captcha',
#  'Captcha',
#  'Captcha',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Captcha',
#  'Captcha',
#  'Not found',
#  'Not found',
#  'Captcha',
#  'Captcha',
#  'Captcha',
#  'Not found',
#  'Not found',
#  'Captcha',
#  'Captcha',
#  'Captcha',
#  'Not found',
#  'Not found',
#  'Captcha',
#  'Captcha',
#  'Captcha',
#  'Not found',
#  'Not found',
#  'Captcha',
#  'Captcha',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Captcha',
#  'Captcha',
#  'Captcha',
#  'Not found',
#  'Not found',
#  'Captcha',
#  'Captcha',
#  'Captcha',
#  {'product_title': "Fantasie über den Choral 'Ein feste Burg ist unser Gott' op. 27 für Orgel - Breitkopf Urtext (EB 8512)",
#   'product_image': 'https://images-eu.ssl-images-amazon.com/images/I/418j2w9CkKL._SY264_BO1,204,203,200_QL40_ML2_.jpg',
#   'product_price': '11,90',
#   'product_details': [{'Herausgeber': 'Breitkopf & Härtel (9. August 1990)'},
#    {'Sprache': 'Deutsch'},
#    {'Taschenbuch': '20 Seiten'},
#    {'ISBN-10': '000417805X'},
#    {'ISBN-13': '978-0004178059'}]},
#  {'product_title': 'Choralfantasie feste burg orgue',
#   'product_image': 'https://images-eu.ssl-images-amazon.com/images/I/418j2w9CkKL._SY291_BO1,204,203,200_QL40_ML2_.jpg',
#   'product_price': '26,09',
#   'product_details': [{'Éditeur': 'BREITKOPF (1 janvier 2000)'},
#    {'Langue': 'Allemand'},
#    {'Broché': '20 pages'},
#    {'ISBN-10': '000417805X'},
#    {'ISBN-13': '978-0004178059'},
#    {"Poids de l'article": '401 g'}]},
#  'Captcha',
#  'Captcha',
#  'Captcha',
#  'Not found',
#  'Not found',
#  'Captcha',
#  'Captcha',
#  'Captcha',
#  'Not found',
#  'Not found',
#  'Captcha',
#  'Captcha',
#  'Captcha',
#  'Not found',
#  'Not found',
#  'Captcha',
#  'Captcha',
#  'Captcha',
#  'Not found',
#  'Not found',
#  'Captcha',
#  'Captcha',
#  'Captcha',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Captcha',
#  'Captcha',
#  'Not found',
#  'Not found',
#  'Captcha',
#  'Captcha',
#  'Captcha',
#  'Not found',
#  'Not found',
#  'Captcha',
#  'Captcha',
#  'Captcha',
#  'Not found',
#  'Not found',
#  'Captcha',
#  'Captcha',
#  'Captcha',
#  'Not found',
#  'Not found',
#  'Captcha',
#  'Captcha',
#  'Captcha',
#  'Not found',
#  'Not found',
#  'Captcha',
#  'Captcha',
#  'Captcha',
#  'Not found',
#  'Not found',
#  'Captcha',
#  'Captcha',
#  'Captcha',
#  {'product_title': "L'ARLESIENNE-SUITE NR. 2 ORCHESTRE",
#   'product_image': 'https://images-eu.ssl-images-amazon.com/images/I/41ELX18MMVL._SX198_BO1,204,203,200_QL40_ML2_.jpg',
#   'product_price': '56,34',
#   'product_details': [{'Herausgeber': 'BREITKOPF (1. Januar 2000)'},
#    {'Sprache': 'Französisch'},
#    {'ISBN-10': '000420736X'},
#    {'ISBN-13': '979-0004207369'}]},
#  {'product_title': "L'arlesienne-suite nr. 2 orchestre",
#   'product_image': 'https://images-eu.ssl-images-amazon.com/images/I/41ELX18MMVL._SX218_BO1,204,203,200_QL40_ML2_.jpg',
#   'product_price': '52,14',
#   'product_details': [{'Éditeur': 'BREITKOPF (1 janvier 2000)'},
#    {'Langue': 'Français'},
#    {'ISBN-10': '000420736X'},
#    {'ISBN-13': '979-0004207369'},
#    {"Poids de l'article": '1 kg'}]},
#  'Captcha',
#  'Captcha',
#  'Captcha',
#  'Not found',
#  'Not found',
#  'Captcha',
#  'Captcha',
#  'Captcha',
#  'Not found',
#  'Not found',
#  'Captcha',
#  'Captcha',
#  'Captcha',
#  'Not found',
#  {'product_title': 'EIN DEUTSCHES REQUIEM 2 KLAV',
#   'product_image': 'https://images-eu.ssl-images-amazon.com/images/I/41kvwEvPVpL._SX198_BO1,204,203,200_QL40_ML2_.jpg',
#   'product_price': '92,00',
#   'product_details': [{'Herausgeber': 'BREITKOPF (1. Januar 2000)'},
#    {'Sprache': 'Französisch'},
#    {'ISBN-10': '000421143X'},
#    {'ISBN-13': '979-0004211434'}]},
#  'Captcha',
#  'Captcha',
#  'Captcha',
#  'Not found',
#  'Not found',
#  'Captcha',
#  'Captcha',
#  'Captcha',
#  'Not found',
#  'Not found',
#  'Captcha',
#  'Captcha',
#  'Captcha',
#  'Not found',
#  'Not found',
#  'Captcha',
#  'Captcha',
#  'Captcha',
#  'Not found',
#  'Not found',
#  'Captcha',
#  'Captcha',
#  'Captcha',
#  'Not found',
#  'Not found',
#  'Captcha',
#  'Captcha',
#  'Captcha',
#  'Not found',
#  'Not found',
#  'Captcha',
#  'Captcha',
#  'Captcha',
#  'Not found',
#  'Not found',
#  'Captcha',
#  'Captcha',
#  'Captcha',
#  'Not found',
#  'Not found',
#  'Captcha',
#  'Captcha',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Captcha',
#  'Captcha',
#  'Captcha',
#  'Not found',
#  'Not found',
#  'Captcha',
#  'Captcha',
#  'Captcha',
#  'Not found',
#  'Not found',
#  'Captcha',
#  'Captcha',
#  'Captcha',
#  'Not found',
#  'Not found',
#  'Not found',
#  'Captcha',
#  'Captcha',
#  'Not found',
#  'Not found',
#  'Captcha',
#  'Captcha',
#  'Captcha',
#  'Not found',
#  'Not found',
#  'Captcha',
#  'Captcha',
#  'Captcha',
#  'Not found',
#  'Not found',
#  'Captcha',
#  'Captcha',
#  'Captcha',
#  'Not found',
#  'Not found',
#  'Captcha',
#  'Captcha',
#  'Captcha',
#  'Not found',
#  'Not found',
#  'Captcha',
#  'Captcha',
#  'Captcha',
#  'Not found']
